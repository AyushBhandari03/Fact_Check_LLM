# %% [markdown]
# # FactCheckLLM: Benchmarking Hallucination Detection using Retrieval-Augmented Verification

# %% [markdown]
# ## Table of Contents
#
# 1. Introduction
# 2. Install Libraries
# 3. Load Dataset
# 4. Load Gemma Model
# 5. Generate Answers
# 6. Retrieve Wikipedia Evidence
# 7. Generate Sentence Embeddings
# 8. Compute Cosine Similarity
# 9. Detect Hallucinations
# 10. Benchmarking
# 11. Evaluation
# 12. Visualizations
# 13. Gradio Demo
# 14. Conclusion

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ## 2. Install Libraries

# %% [markdown]
# ## 3. Load Dataset

# %% [markdown]
# ## 4. Load Gemma Model

# %% [markdown]
# ## 5. Generate Answers

# %% [markdown]
# ## 6. Retrieve Wikipedia Evidence

# %% [markdown]
# ## 7. Generate Sentence Embeddings

# %% [markdown]
# ## 8. Compute Cosine Similarity

# %% [markdown]
# ## 9. Detect Hallucinations

# %% [markdown]
# ## 10. Benchmarking

# %% [markdown]
# ### 10.1 Embedding Models (MiniLM vs BGE)

# %% [markdown]
# ### 10.2 Retrieval vs No Retrieval

# %% [markdown]
# ### 10.3 Similarity Threshold Analysis

# %% [markdown]
# ## 11. Evaluation

# %% [markdown]
# ## 12. Visualizations

# %% [markdown]
# ## 13. Gradio Demo

# %% [markdown]
# ## 14. Conclusion
